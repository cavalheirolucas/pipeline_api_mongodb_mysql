# %%
from conexao import pipeline

# %%
pipe = pipeline('db_teste', 'teste')
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
api_url = 'https://labdados.com/produtos'
pipe.extract_and_save(api_url)

# %%
pipe.client.close()

# %%
from scripts.transform import transform_data

# %%
transform = transform_data('db_teste', 'teste')
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
path = 'lista_produtos_test.csv'
transform.transform_and_save(path)

# %%
from scripts.pipeline import pipeline

# %%
db_name = 'db'
collection_name = 'prd'

pipe = pipeline(db_name, collection_name)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
api_url = 'https://labdados.com/produtos'
pipe.extract_and_save(api_url)

# %%
path = 'lista_produtos_test2.csv'
pipe.transform_and_save(path)

# %%
path = '/home/lucascavalheiro/pipeline-python-mongo-mysql/lista_produtos_test2.csv'
pipe.save(path, db_name, collection_name)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/pipeline-python-mongo-mysql/venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py:611, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     610         query = query.encode("utf-8")
# --> 611     self._cmysql.query(
#     612         query,
#     613         raw=raw,
#     614         buffered=buffered,
#     615         raw_as_string=raw_as_string,
#     616         query_attrs=self._query_attrs,
#     617     )
#     618 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'dbprodutos.prd' doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[15], line 2
#       1 path = '/home/lucascavalheiro/pipeline-python-mongo-mysql/lista_produtos_test2.csv'
# ...
